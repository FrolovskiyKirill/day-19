# %% [markdown]
# <a href="https://colab.research.google.com/github/FrolovskiyKirill/day-19/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/data.csv')

# %%
from pandas.core.common import random_state
def info_temp(data):
  display(data.sample(5, random_state=1))
  display(data.info())
  display(pd.DataFrame(round((df.isna().mean() * 100), 2)).style.background_gradient('coolwarm'))

# %%
info_temp(df)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 1383          0  353802.811675         37   среднее             1
# 300           1    -359.193975         33   СРЕДНЕЕ             1
# 6565          2   -1064.854333         35   среднее             1
# 17027         0            NaN         48    высшее             0
# 4077          0   -7059.100220         45    высшее             0
#
#           family_status  family_status_id gender income_type  debt  \
# 1383     вдовец / вдова                 2      F   пенсионер     0
# 300    гражданский брак                 1      M   сотрудник     0
# 6565   гражданский брак                 1      F   компаньон     0
# 17027  гражданский брак                 1      F   сотрудник     0
# 4077   гражданский брак                 1      F   компаньон     1
#
#         total_income                     purpose
# 1383   216452.226085  строительство недвижимости
# 300    223001.623994       на проведение свадьбы
# ...
